# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('datasets/cost_revenue_clean.csv')
df
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                    110000             11000000
# 1                    200000              8000000
# 2                    100000              3000000
# 3                    245000             22000000
# 4                   3900000              9000000
# ...                     ...                  ...
# 5029               55000000            376856949
# 5030               40000000            166893990
# 5031              185000000            561137727
# 5032              175000000            140012608
# 5033               42000000             57850343
#
# [5034 rows x 2 columns]

# %%
X = df['production_budget_usd']
y = df['worldwide_gross_usd']

plt.figure(figsize=(10,6)) # untuk mengatur ukuran diagram
plt.scatter(X, y, alpha=0.3) # alpha : untuk membuat efek transparant
plt.title('Film Cost vs. Global Revenue')
plt.xlabel('Production Budget ($)')
plt.ylabel('Worlwide Gross ($)')

plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)

plt.show()

# %% [markdown]
# # Linear Regression Implementation

# %%
regression = LinearRegression()
regression.fit(X.values.reshape(-1, 1), y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Slope coefficient:
regression.coef_
# Out:
# array([3.11150918])

# %%
# intercept
regression.intercept_
# Out:
# -7236192.729139626

# %% [markdown]
# ## *Loh.. lalu garis yang seperti teori tadi letaknya dimana?*
#
# Oke, mari kita buat

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, y, alpha=0.3)

# this
plt.plot(X, regression.predict(X.values.reshape(-1, 1)), color= 'red', linewidth='4')

plt.title('Film Cost vs. Global Revenue')
plt.xlabel('Production Budget ($)')
plt.ylabel('Worlwide Gross ($)')

plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)

plt.show()

# %% [markdown]
# # Evaluation

# %%
#Getting r square from Regression
regression.score(X.values.reshape(-1, 1), y)
# Out:
# 0.5496485356985729
